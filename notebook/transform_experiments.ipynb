# %% [markdown]
# #### transform.py実装前確認

# %%
import pandas as pd

# スクレイピング結果csvを読み込んで、「会社名」データ確認
df = pd.read_csv("/app/data/rikunabi.csv")
print(df["会社名"].head())
# Out:
# 0    三菱UFJアセットマネジメント株式会社
# 1        株式会社ネットプロテクションズ
# 2        株式会社ネットプロテクションズ
# 3              楽天カード株式会社
# 4           株式会社シー・エス・イー
# Name: 会社名, dtype: object
